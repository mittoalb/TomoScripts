# %%
import numpy as np
import matplotlib.pyplot as plt
from skimage.transform import radon, iradon
from scipy.ndimage import rotate
from skimage.draw import disk

def EST_Angles(num_projections):
    """
    Generate projection angles that are equally spaced in Fourier space.

    Parameters:
    - num_projections: int, number of projections to generate.

    Returns:
    - theta: 1D array, the projection angles.
    """
    return np.arcsin(np.linspace(-1, 1, num_projections)) * 180 / np.pi

def make_phantom(size, num_disks):
    """
    Create a foam-like phantom with multiple disks of varying sizes and intensities.

    Parameters:
    - size: int, the size (height and width) of the phantom image.
    - num_disks: int, the number of disks to generate.

    Returns:
    - phantom: 2D array, the generated phantom image.
    """
    phantom = np.zeros((size, size))

    rng = np.random.default_rng()
    for _ in range(num_disks):
        # Random position
        x, y = rng.integers(0, size, size=2)
        # Random radius
        radius = rng.integers(5, size // 10)
        # Random intensity
        intensity = rng.random()

        rr, cc = disk((x, y), radius, shape=phantom.shape)
        phantom[rr, cc] += intensity
        phantom = np.clip(phantom, 0, 1)  # Ensure intensity stays within [0, 1]

    return phantom

def EST_reco(sinogram, theta, num_iterations=200, tolerance=1e-5, learning_rate=0.00005):
    """
    Perform Equally Sloped Tomography (EST) reconstruction using simple gradient descent.

    Parameters:
    - sinogram: 2D array, the sinogram data (projections).
    - theta: 1D array, the projection angles.
    - num_iterations: int, number of iterations for the EST algorithm.
    - tolerance: float, tolerance for early stopping based on maximum error change.
    - learning_rate: float, step size for the updates.

    Returns:
    - reconstructed_image: 2D array, the reconstructed image.
    """
    num_projections, sx = sinogram.shape

    # Initial guess using Filtered Back Projection (FBP)
    initial_guess = iradon(np.rot90(sinogram, -1), theta=theta, circle=True)
    estimated_image = initial_guess.copy()

    previous_error = np.inf

    for iteration in range(num_iterations):
        # Forward projection
        projections = np.zeros((num_projections, sx))

        for i, angle in enumerate(theta):
            rotated_image = rotate(estimated_image, angle, reshape=False, order=1)
            projection = np.sum(rotated_image, axis=0)

            if projection.shape[0] > sx:
                projection = projection[:sx]
            elif projection.shape[0] < sx:
                projection = np.pad(projection, (0, sx - projection.shape[0]), 'constant')

            projections[i, :] = projection

        # Compute error
        error = sinogram - projections
        max_error = np.max(np.abs(error))

        print(f"Iteration {iteration + 1}/{num_iterations} - Max error: {max_error}")

        # Early stopping if error change is below the tolerance
        if np.abs(previous_error - max_error) < tolerance:
            print(f"Convergence reached at iteration {iteration + 1}")
            break

        previous_error = max_error

        # Backproject the error
        backprojected_error = np.zeros_like(estimated_image)
        for i, angle in enumerate(theta):
            expanded_error = np.zeros_like(estimated_image)
            expanded_error[:, :sx] = error[i, :].reshape(-1, sx)
            rotated_error = rotate(expanded_error, -angle, reshape=False, order=1)
            backprojected_error += rotated_error

        # Normalize the backprojected error to avoid excessive accumulation
        if np.max(np.abs(backprojected_error)) != 0:
            backprojected_error /= np.max(np.abs(backprojected_error))

        # Apply gradient descent update
        estimated_image += learning_rate * (backprojected_error / num_projections)
        estimated_image = np.maximum(estimated_image, 0)  # Apply non-negativity constraint

    return estimated_image

def make_sino(phantom, theta):
    sinogram = radon(phantom, theta=theta, circle=True)
    return np.rot90(sinogram, 1)

# Example usage
if __name__ == "__main__":
    size = 128
    num_disks = 30
    phantom = make_phantom(size, num_disks)

    num_projections = 160 
    theta = EST_Angles(num_projections)
    sinogram = make_sino(phantom, theta)

    # Perform EST reconstruction
    EST_data = EST_reco(sinogram, theta, num_iterations=500, learning_rate=0.0005)

    # Perform FBP reconstruction
    FBP_data = iradon(np.rot90(sinogram, -1), theta=theta, circle=True)

    # Plot results
    plt.figure(figsize=(18, 6))
    plt.subplot(1, 4, 1)
    plt.title("Phantom")
    plt.imshow(phantom, cmap='gray')
    plt.axis('off')

    plt.subplot(1, 4, 2)
    plt.title("Sinogram")
    plt.imshow(sinogram, cmap='gray', aspect='auto')
    plt.axis('off')

    plt.subplot(1, 4, 3)
    plt.title("Reconstructed Image (EST)")
    plt.imshow(reconstructed_image_est, cmap='gray')
    plt.axis('off')

    plt.subplot(1, 4, 4)
    plt.title("Reconstructed Image (FBP)")
    plt.imshow(reconstructed_image_fbp, cmap='gray')
    plt.axis('off')

    plt.show()
# Out:
# Iteration 1/500 - Max error: 42.82404722139289
# Iteration 2/500 - Max error: 36.24190832534727
# Iteration 3/500 - Max error: 36.24189340675716
# Iteration 4/500 - Max error: 36.241878485469215
# Iteration 5/500 - Max error: 36.241863561497155
# Iteration 6/500 - Max error: 36.24184863484496
# Iteration 7/500 - Max error: 36.241833705514395
# Iteration 8/500 - Max error: 36.24181877350624
# Iteration 9/500 - Max error: 36.24180383882138
# Iteration 10/500 - Max error: 36.24178890146031
# Iteration 11/500 - Max error: 36.24177396142325
# Iteration 12/500 - Max error: 36.24175901871035
# Iteration 13/500 - Max error: 36.241744073321584
# Iteration 14/500 - Max error: 36.24172912525699
# Iteration 15/500 - Max error: 36.241714174516595
# Iteration 16/500 - Max error: 36.241699221100376
# Iteration 17/500 - Max error: 36.24168426500835
# Iteration 18/500 - Max error: 36.24166930624051
# Iteration 19/500 - Max error: 36.241654344796814
# Iteration 20/500 - Max error: 36.24163938067724
# Iteration 21/500 - Max error: 36.24162441388181
# Iteration 22/500 - Max error: 36.24160944441047
# Iteration 23/500 - Max error: 36.24159447226316
# Iteration 24/500 - Max error: 36.24157949743992
# Iteration 25/500 - Max error: 36.24156451994065
# Iteration 26/500 - Max error: 36.241549539765316
# Iteration 27/500 - Max error: 36.2415345569139
# Iteration 28/500 - Max error: 36.241519571386306
# Iteration 29/500 - Max error: 36.241504583182504
# Iteration 30/500 - Max error: 36.24148959230247
# Iteration 31/500 - Max error: 36.24147459874613
# Iteration 32/500 - Max error: 36.241459602513444
# Iteration 33/500 - Max error: 36.241444603604386
# Iteration 34/500 - Max error: 36.241429602018904
# Iteration 35/500 - Max error: 36.24141459775691
# Iteration 36/500 - Max error: 36.24139959081839
# Iteration 37/500 - Max error: 36.24138458120328
# Iteration 38/500 - Max error: 36.241369568911516
# Iteration 39/500 - Max error: 36.24135455394307
# Iteration 40/500 - Max error: 36.24133953629786
# Iteration 41/500 - Max error: 36.24132451597586
# Iteration 42/500 - Max error: 36.24130949297718
# Iteration 43/500 - Max error: 36.241294467301756
# Iteration 44/500 - Max error: 36.241279438949576
# Iteration 45/500 - Max error: 36.241264407920525
# Iteration 46/500 - Max error: 36.241249374214604
# Iteration 47/500 - Max error: 36.241234337831756
# Iteration 48/500 - Max error: 36.241219298771895
# Iteration 49/500 - Max error: 36.24120425703501
# Iteration 50/500 - Max error: 36.24118921262101
# Iteration 51/500 - Max error: 36.24117416552987
# Iteration 52/500 - Max error: 36.24115911576151
# Iteration 53/500 - Max error: 36.24114406331592
# Iteration 54/500 - Max error: 36.24112900819301
# Iteration 55/500 - Max error: 36.24111395039275
# Iteration 56/500 - Max error: 36.24109888991506
# Iteration 57/500 - Max error: 36.241083826759905
# Iteration 58/500 - Max error: 36.24106876092723
# Iteration 59/500 - Max error: 36.24105369241696
# Iteration 60/500 - Max error: 36.24103862122908
# Iteration 61/500 - Max error: 36.24102354736354
# Iteration 62/500 - Max error: 36.24100847082025
# Iteration 63/500 - Max error: 36.24099339159919
# Iteration 64/500 - Max error: 36.240978309700296
# Iteration 65/500 - Max error: 36.24096322512349
# Iteration 66/500 - Max error: 36.24094813786877
# Iteration 67/500 - Max error: 36.24093304793607
# Iteration 68/500 - Max error: 36.2409179553253
# Iteration 69/500 - Max error: 36.240902860036456
# Iteration 70/500 - Max error: 36.24088776206946
# Iteration 71/500 - Max error: 36.24087266142427
# Iteration 72/500 - Max error: 36.24085755810083
# Iteration 73/500 - Max error: 36.24084245209907
# Iteration 74/500 - Max error: 36.24082734341896
# Iteration 75/500 - Max error: 36.24081223206045
# Iteration 76/500 - Max error: 36.24079711802348
# Iteration 77/500 - Max error: 36.24078200130797
# Iteration 78/500 - Max error: 36.2407668819139
# Iteration 79/500 - Max error: 36.24075175984123
# Iteration 80/500 - Max error: 36.24073663508984
# Iteration 81/500 - Max error: 36.24072150765974
# Iteration 82/500 - Max error: 36.24070637755085
# Iteration 83/500 - Max error: 36.24069124476313
# Iteration 84/500 - Max error: 36.24067610929653
# Iteration 85/500 - Max error: 36.240660971150945
# Iteration 86/500 - Max error: 36.240645830326415
# Iteration 87/500 - Max error: 36.240630686822804
# Iteration 88/500 - Max error: 36.24061554064008
# Iteration 89/500 - Max error: 36.24060039177823
# Iteration 90/500 - Max error: 36.240585240237145
# Iteration 91/500 - Max error: 36.2405700860168
# Iteration 92/500 - Max error: 36.24055492911715
# Iteration 93/500 - Max error: 36.24053976953813
# Iteration 94/500 - Max error: 36.240524607279674
# Iteration 95/500 - Max error: 36.24050944234176
# Iteration 96/500 - Max error: 36.24049427472432
# Iteration 97/500 - Max error: 36.240479104427294
# Iteration 98/500 - Max error: 36.24046393145064
# Iteration 99/500 - Max error: 36.240448755794304
# Iteration 100/500 - Max error: 36.24043357745823
# Iteration 101/500 - Max error: 36.240418396442365
# Iteration 102/500 - Max error: 36.240403212746635
# Iteration 103/500 - Max error: 36.24038802637106
# Iteration 104/500 - Max error: 36.24037283731549
# Iteration 105/500 - Max error: 36.240357645579934
# Iteration 106/500 - Max error: 36.24034245116434
# Iteration 107/500 - Max error: 36.24032725406859
# Iteration 108/500 - Max error: 36.24031205429269
# Iteration 109/500 - Max error: 36.240296851836575
# Iteration 110/500 - Max error: 36.24028164670019
# Iteration 111/500 - Max error: 36.24026643888349
# Iteration 112/500 - Max error: 36.2402512283864
# Iteration 113/500 - Max error: 36.24023601520888
# Iteration 114/500 - Max error: 36.24022079935087
# Iteration 115/500 - Max error: 36.24020558081236
# Iteration 116/500 - Max error: 36.24019035959322
# Iteration 117/500 - Max error: 36.24017513569345
# Iteration 118/500 - Max error: 36.240159909113224
# Iteration 119/500 - Max error: 36.24014467985252
# Iteration 120/500 - Max error: 36.24012944791128
# Iteration 121/500 - Max error: 36.24011421328943
# Iteration 122/500 - Max error: 36.24009897598695
# Iteration 123/500 - Max error: 36.240083736003776
# Iteration 124/500 - Max error: 36.24006849333982
# Iteration 125/500 - Max error: 36.24005324799508
# Iteration 126/500 - Max error: 36.24003799996948
# Iteration 127/500 - Max error: 36.24002274926296
# Iteration 128/500 - Max error: 36.240007495875496
# Iteration 129/500 - Max error: 36.23999223980697
# Iteration 130/500 - Max error: 36.2399769810574
# Iteration 131/500 - Max error: 36.23996171962672
# Iteration 132/500 - Max error: 36.23994645551484
# Iteration 133/500 - Max error: 36.239931188721734
# Iteration 134/500 - Max error: 36.23991591924735
# Iteration 135/500 - Max error: 36.239900647091616
# Iteration 136/500 - Max error: 36.23988537225449
# Iteration 137/500 - Max error: 36.239870094735934
# Iteration 138/500 - Max error: 36.23985481453588
# Iteration 139/500 - Max error: 36.239839531654255
# Iteration 140/500 - Max error: 36.23982424609104
# Iteration 141/500 - Max error: 36.23980895784618
# Iteration 142/500 - Max error: 36.2397936669196
# Iteration 143/500 - Max error: 36.23977837331125
# Iteration 144/500 - Max error: 36.239763077021095
# Iteration 145/500 - Max error: 36.239747778049065
# Iteration 146/500 - Max error: 36.23973247639512
# Iteration 147/500 - Max error: 36.23971717205917
# Iteration 148/500 - Max error: 36.239701865041226
# Iteration 149/500 - Max error: 36.23968655534118
# Iteration 150/500 - Max error: 36.23967124295899
# Iteration 151/500 - Max error: 36.23965592789463
# Iteration 152/500 - Max error: 36.239640610148015
# Iteration 153/500 - Max error: 36.2396252897191
# Iteration 154/500 - Max error: 36.23960996660784
# Iteration 155/500 - Max error: 36.23959464081417
# Iteration 156/500 - Max error: 36.239579312338066
# Iteration 157/500 - Max error: 36.239563981179444
# Iteration 158/500 - Max error: 36.23954864733827
# Iteration 159/500 - Max error: 36.23953331081448
# Iteration 160/500 - Max error: 36.23951797160803
# Iteration 161/500 - Max error: 36.239502629718935
# Iteration 162/500 - Max error: 36.23948728514709
# Iteration 163/500 - Max error: 36.23947193789251
# Iteration 164/500 - Max error: 36.23945658795521
# Iteration 165/500 - Max error: 36.23944123533518
# Iteration 166/500 - Max error: 36.2394258800324
# Iteration 167/500 - Max error: 36.239410522046775
# Iteration 168/500 - Max error: 36.23939516137827
# Iteration 169/500 - Max error: 36.23937979802685
# Iteration 170/500 - Max error: 36.23936443199244
# Iteration 171/500 - Max error: 36.23934906327498
# Iteration 172/500 - Max error: 36.23933369187445
# Iteration 173/500 - Max error: 36.23931831779076
# Iteration 174/500 - Max error: 36.239302941023865
# Iteration 175/500 - Max error: 36.23928756157372
# Iteration 176/500 - Max error: 36.23927217944026
# Iteration 177/500 - Max error: 36.23925679462345
# Iteration 178/500 - Max error: 36.23924140712323
# Iteration 179/500 - Max error: 36.23922601693954
# Iteration 180/500 - Max error: 36.23921062407234
# Iteration 181/500 - Max error: 36.23919522852155
# Iteration 182/500 - Max error: 36.23917983028717
# Iteration 183/500 - Max error: 36.23916442936907
# Iteration 184/500 - Max error: 36.23914902576725
# Iteration 185/500 - Max error: 36.239133619481656
# Iteration 186/500 - Max error: 36.23911821051219
# Iteration 187/500 - Max error: 36.23910279885885
# Iteration 188/500 - Max error: 36.23908738452158
# Iteration 189/500 - Max error: 36.239071967500294
# Iteration 190/500 - Max error: 36.23905654779496
# Iteration 191/500 - Max error: 36.23904112540551
# Iteration 192/500 - Max error: 36.23902570033191
# Iteration 193/500 - Max error: 36.23901027257408
# Iteration 194/500 - Max error: 36.238994842132
# Iteration 195/500 - Max error: 36.23897940900558
# Iteration 196/500 - Max error: 36.23896397319483
# Iteration 197/500 - Max error: 36.2389485346996
# Iteration 198/500 - Max error: 36.23893309351992
# Iteration 199/500 - Max error: 36.2389176496557
# Iteration 200/500 - Max error: 36.238902203106875
# Iteration 201/500 - Max error: 36.238886753873444
# Iteration 202/500 - Max error: 36.23887130195531
# Iteration 203/500 - Max error: 36.2388558473524
# Iteration 204/500 - Max error: 36.23884039006471
# Iteration 205/500 - Max error: 36.23882493009217
# Iteration 206/500 - Max error: 36.23880946743472
# Iteration 207/500 - Max error: 36.23879400209229
# Iteration 208/500 - Max error: 36.23877853406486
# Iteration 209/500 - Max error: 36.238763063352366
# Iteration 210/500 - Max error: 36.238747589954755
# Iteration 211/500 - Max error: 36.23873211387196
# Iteration 212/500 - Max error: 36.23871663510395
# Iteration 213/500 - Max error: 36.23870115365064
# Iteration 214/500 - Max error: 36.23868566951199
# Iteration 215/500 - Max error: 36.23867018268798
# Iteration 216/500 - Max error: 36.23865469317852
# Iteration 217/500 - Max error: 36.23863920098354
# Iteration 218/500 - Max error: 36.23862370610304
# Iteration 219/500 - Max error: 36.23860820853694
# Iteration 220/500 - Max error: 36.23859270828524
# Iteration 221/500 - Max error: 36.23857720534803
# Iteration 222/500 - Max error: 36.238561699725246
# Iteration 223/500 - Max error: 36.238546191416845
# Iteration 224/500 - Max error: 36.238530680422755
# Iteration 225/500 - Max error: 36.23851516674292
# Iteration 226/500 - Max error: 36.23849965037732
# Iteration 227/500 - Max error: 36.238484131325855
# Iteration 228/500 - Max error: 36.238468609588516
# Iteration 229/500 - Max error: 36.238453085165226
# Iteration 230/500 - Max error: 36.23843755805594
# Iteration 231/500 - Max error: 36.23842202826057
# Iteration 232/500 - Max error: 36.23840649577911
# Iteration 233/500 - Max error: 36.2383909606115
# Iteration 234/500 - Max error: 36.23837542275766
# Iteration 235/500 - Max error: 36.23835988221754
# Iteration 236/500 - Max error: 36.23834433899111
# Iteration 237/500 - Max error: 36.238328793078324
# Iteration 238/500 - Max error: 36.23831324447909
# Iteration 239/500 - Max error: 36.238297693193374
# Iteration 240/500 - Max error: 36.23828213922113
# Iteration 241/500 - Max error: 36.2382665825623
# Iteration 242/500 - Max error: 36.23825102321681
# Iteration 243/500 - Max error: 36.23823546118464
# Iteration 244/500 - Max error: 36.23821989646571
# Iteration 245/500 - Max error: 36.23820432905998
# Iteration 246/500 - Max error: 36.2381887589674
# Iteration 247/500 - Max error: 36.23817318618789
# Iteration 248/500 - Max error: 36.238157610721444
# Iteration 249/500 - Max error: 36.23814203256795
# Iteration 250/500 - Max error: 36.23812645172741
# Iteration 251/500 - Max error: 36.238110868199755
# Iteration 252/500 - Max error: 36.23809528198491
# Iteration 253/500 - Max error: 36.23807969308284
# Iteration 254/500 - Max error: 36.238064101493464
# Iteration 255/500 - Max error: 36.238048507216774
# Iteration 256/500 - Max error: 36.238032910252684
# Iteration 257/500 - Max error: 36.23801731060116
# Iteration 258/500 - Max error: 36.23800170826213
# Iteration 259/500 - Max error: 36.23798610323556
# Iteration 260/500 - Max error: 36.23797049552138
# Iteration 261/500 - Max error: 36.237954885119535
# Iteration 262/500 - Max error: 36.23793927202999
# Iteration 263/500 - Max error: 36.237923656252676
# Iteration 264/500 - Max error: 36.23790803778755
# Iteration 265/500 - Max error: 36.237892416634544
# Iteration 266/500 - Max error: 36.2378767927936
# Iteration 267/500 - Max error: 36.23786116626469
# Iteration 268/500 - Max error: 36.23784553704776
# Iteration 269/500 - Max error: 36.23782990514275
# Iteration 270/500 - Max error: 36.23781427054958
# Iteration 271/500 - Max error: 36.237798633268234
# Iteration 272/500 - Max error: 36.23778299329864
# Iteration 273/500 - Max error: 36.23776735064074
# Iteration 274/500 - Max error: 36.2377517052945
# Iteration 275/500 - Max error: 36.23773605725984
# Iteration 276/500 - Max error: 36.23772040653673
# Iteration 277/500 - Max error: 36.237704753125115
# Iteration 278/500 - Max error: 36.23768909702491
# Iteration 279/500 - Max error: 36.2376734382361
# Iteration 280/500 - Max error: 36.23765777675861
# Iteration 281/500 - Max error: 36.23764211259242
# Iteration 282/500 - Max error: 36.23762644573743
# Iteration 283/500 - Max error: 36.237610776193684
# Iteration 284/500 - Max error: 36.237595103961134
# Iteration 285/500 - Max error: 36.23757942903975
# Iteration 286/500 - Max error: 36.237563751429434
# Iteration 287/500 - Max error: 36.23754807113017
# Iteration 288/500 - Max error: 36.23753238814189
# Iteration 289/500 - Max error: 36.237516702464546
# Iteration 290/500 - Max error: 36.237501014098086
# Iteration 291/500 - Max error: 36.23748532304244
# Iteration 292/500 - Max error: 36.23746962929759
# Iteration 293/500 - Max error: 36.23745393286344
# Iteration 294/500 - Max error: 36.237438233739965
# Iteration 295/500 - Max error: 36.2374225319271
# Iteration 296/500 - Max error: 36.237406827424806
# Iteration 297/500 - Max error: 36.237391120233
# Iteration 298/500 - Max error: 36.23737541035163
# Iteration 299/500 - Max error: 36.2373596977807
# Iteration 300/500 - Max error: 36.23734398252009
# Iteration 301/500 - Max error: 36.23732826456978
# Iteration 302/500 - Max error: 36.237312543929704
# Iteration 303/500 - Max error: 36.237296820599816
# Iteration 304/500 - Max error: 36.23728109458007
# Iteration 305/500 - Max error: 36.237265365870385
# Iteration 306/500 - Max error: 36.23724963447073
# Iteration 307/500 - Max error: 36.23723390038105
# Iteration 308/500 - Max error: 36.237218163601284
# Iteration 309/500 - Max error: 36.2372024241314
# Iteration 310/500 - Max error: 36.23718668197131
# Iteration 311/500 - Max error: 36.237170937120965
# Iteration 312/500 - Max error: 36.23715518958034
# Iteration 313/500 - Max error: 36.23713943934946
# Iteration 314/500 - Max error: 36.23712368642842
# Iteration 315/500 - Max error: 36.23710793081712
# Iteration 316/500 - Max error: 36.237092172515545
# Iteration 317/500 - Max error: 36.237076411523745
# Iteration 318/500 - Max error: 36.237060647841616
# Iteration 319/500 - Max error: 36.237044881469146
# Iteration 320/500 - Max error: 36.23702911240626
# Iteration 321/500 - Max error: 36.2370133406529
# Iteration 322/500 - Max error: 36.236997566209055
# Iteration 323/500 - Max error: 36.23698178907461
# Iteration 324/500 - Max error: 36.23696600924957
# Iteration 325/500 - Max error: 36.23695022673384
# Iteration 326/500 - Max error: 36.236934441527396
# Iteration 327/500 - Max error: 36.236918653630156
# Iteration 328/500 - Max error: 36.23690286304209
# Iteration 329/500 - Max error: 36.236887069763135
# Iteration 330/500 - Max error: 36.23687127379323
# Iteration 331/500 - Max error: 36.23685547513233
# Iteration 332/500 - Max error: 36.23683967378066
# Iteration 333/500 - Max error: 36.2368238697383
# Iteration 334/500 - Max error: 36.23680806300527
# Iteration 335/500 - Max error: 36.236792253581484
# Iteration 336/500 - Max error: 36.23677644146686
# Iteration 337/500 - Max error: 36.2367606266614
# Iteration 338/500 - Max error: 36.23674480916502
# Iteration 339/500 - Max error: 36.23672898897766
# Iteration 340/500 - Max error: 36.23671316609927
# Iteration 341/500 - Max error: 36.236697340529815
# Iteration 342/500 - Max error: 36.23668151226924
# Iteration 343/500 - Max error: 36.236665681317476
# Iteration 344/500 - Max error: 36.236649847674464
# Iteration 345/500 - Max error: 36.23663401134014
# Iteration 346/500 - Max error: 36.236618172314515
# Iteration 347/500 - Max error: 36.23660233059749
# Iteration 348/500 - Max error: 36.236586486189
# Iteration 349/500 - Max error: 36.23657063908901
# Iteration 350/500 - Max error: 36.23655478929744
# Iteration 351/500 - Max error: 36.23653893681429
# Iteration 352/500 - Max error: 36.23652308163946
# Iteration 353/500 - Max error: 36.2365072237729
# Iteration 354/500 - Max error: 36.2364913632146
# Iteration 355/500 - Max error: 36.236475499964456
# Iteration 356/500 - Max error: 36.236459634022424
# Iteration 357/500 - Max error: 36.23644376538845
# Iteration 358/500 - Max error: 36.236427894062544
# Iteration 359/500 - Max error: 36.23641202004456
# Iteration 360/500 - Max error: 36.23639614333449
# Iteration 361/500 - Max error: 36.236380263932276
# Iteration 362/500 - Max error: 36.23636438183786
# Iteration 363/500 - Max error: 36.23634849705118
# Iteration 364/500 - Max error: 36.2363326095722
# Iteration 365/500 - Max error: 36.236316719400875
# Iteration 366/500 - Max error: 36.23630082653712
# Iteration 367/500 - Max error: 36.236284930980915
# Iteration 368/500 - Max error: 36.23626903273219
# Iteration 369/500 - Max error: 36.23625313179089
# Iteration 370/500 - Max error: 36.23623722815694
# Iteration 371/500 - Max error: 36.23622132183032
# Iteration 372/500 - Max error: 36.23620541281098
# Iteration 373/500 - Max error: 36.23618950109885
# Iteration 374/500 - Max error: 36.23617358669385
# Iteration 375/500 - Max error: 36.23615766959601
# Iteration 376/500 - Max error: 36.236141749805356
# Iteration 377/500 - Max error: 36.23612582732214
